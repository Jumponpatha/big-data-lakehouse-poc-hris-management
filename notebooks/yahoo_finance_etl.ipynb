# %%
# !pip install curl_cffi --default-timeout=200 --no-cache-dir
# !pip install yfinance --no-cache-dir

# %%
# !pip uninstall -y yfinance multitasking
# !pip install "yfinance<0.2.40" "multitasking<0.0.12"
# Out:
# Found existing installation: yfinance 0.2.66
# Uninstalling yfinance-0.2.66:
#   Successfully uninstalled yfinance-0.2.66
# Found existing installation: multitasking 0.0.12
# Uninstalling multitasking-0.0.12:
#   Successfully uninstalled multitasking-0.0.12
# ...
#      |████████████████████████████████| 73 kB 900 kB/s eta 0:00:011
# ...
#      |████████████████████████████████| 5.1 MB 1.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 112 kB 4.9 MB/s eta 0:00:01
# ...
#   WARNING: The script sample is installed in '/home/spark/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
import yfinance as yf

# %%
import sys
sys.version
# Out:
# '3.8.10 (default, Mar 18 2025, 20:04:55) \n[GCC 9.4.0]'

# %%
# Define the ticker symbol
ticker_symbol = "GOOGL"

# Create a Ticker object
ticker = yf.Ticker(ticker_symbol)

# Fetch historical market data
historical_data = ticker.history(period="1y")  # data for the last year
print("Historical Data:")
print(historical_data)

# Fetch basic financials
financials = ticker.financials
print("\nFinancials:")
print(financials)

# Fetch stock actions like dividends and splits
actions = ticker.actions
print("\nStock Actions:")
print(actions)
# Out:
# Historical Data:
#                                  Open        High         Low       Close  \
# Date
# 2024-11-05 00:00:00-05:00  168.686084  169.781260  168.098678  168.994736
# 2024-11-06 00:00:00-05:00  173.036908  176.163121  172.738222  175.735001
# 2024-11-07 00:00:00-05:00  176.631074  180.284959  176.412038  179.956406
# 2024-11-08 00:00:00-05:00  179.856814  180.105717  177.298106  177.566925
# 2024-11-11 00:00:00-05:00  177.795903  179.757255  177.686386  179.558136
# ...                               ...         ...         ...         ...
# 2025-10-30 00:00:00-04:00  291.589996  291.589996  280.059998  281.480011
# 2025-10-31 00:00:00-04:00  283.209991  286.000000  277.029999  281.190002
# 2025-11-03 00:00:00-05:00  282.179993  285.529999  279.799988  283.720001
# 2025-11-04 00:00:00-05:00  276.750000  281.269989  276.260010  277.540009
# 2025-11-05 00:00:00-05:00  278.894989  284.885010  277.339996  282.940002
#
# ...

# %%
# Define the ticker symbol
ticker_symbol = "MSFT"

# Create a Ticker object
ticker = yf.Ticker(ticker_symbol)

# Fetch historical market data for the last 30 days
historical_data = ticker.history(period="1mo")  # data for the last month

# Display a summary of the fetched data
print(f"Summary of Historical Data for {ticker_symbol}:")
print(historical_data[['Open', 'High', 'Low', 'Close', 'Volume']])
# Out:
# Summary of Historical Data for MSFT:
#                                  Open        High         Low       Close  \
# Date
# 2025-10-06 00:00:00-04:00  518.609985  531.030029  518.200012  528.570007
# 2025-10-07 00:00:00-04:00  528.289978  529.799988  521.440002  523.979980
# 2025-10-08 00:00:00-04:00  523.280029  526.950012  523.090027  524.849976
# 2025-10-09 00:00:00-04:00  522.340027  524.330017  517.400024  522.400024
# 2025-10-10 00:00:00-04:00  519.640015  523.580017  509.630005  510.959991
# 2025-10-13 00:00:00-04:00  516.409973  516.409973  511.679993  514.049988
# 2025-10-14 00:00:00-04:00  510.230011  515.280029  506.000000  513.570007
# 2025-10-15 00:00:00-04:00  514.960022  517.190002  510.000000  513.429993
# 2025-10-16 00:00:00-04:00  512.580017  516.849976  508.130005  511.609985
# 2025-10-17 00:00:00-04:00  509.040009  515.479980  507.309998  513.580017
# 2025-10-20 00:00:00-04:00  514.609985  518.700012  513.429993  516.789978
# ...

# %%
# !pip install matplotlib

# %%
import yfinance as yf
t = yf.Ticker("XYZ.MX")
print(t.history(period="5y").tail())
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2025-10-29 00:00:00-06:00  1430.000000  1430.000000  1400.000000  1400.000000
# 2025-10-30 00:00:00-06:00  1409.989990  1409.989990  1369.290039  1369.290039
# 2025-10-31 00:00:00-06:00  1405.180054  1405.180054  1405.180054  1405.180054
# 2025-11-03 00:00:00-06:00  1365.000000  1365.000000  1365.000000  1365.000000
# 2025-11-04 00:00:00-06:00  1365.000000  1365.000000  1365.000000  1365.000000
#
#                            Volume  Dividends  Stock Splits
# Date
# 2025-10-29 00:00:00-06:00      37        0.0           0.0
# 2025-10-30 00:00:00-06:00    4070        0.0           0.0
# 2025-10-31 00:00:00-06:00     843        0.0           0.0
# 2025-11-03 00:00:00-06:00      43        0.0           0.0
# 2025-11-04 00:00:00-06:00       4        0.0           0.0

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# Download data
data = yf.download("GOOGL", start="2025-05-01", end="2025-11-04")

# Plot Close price
plt.figure(figsize=(12,6))
plt.plot(data["Close"])
plt.title("AAPL Closing Price")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.grid(True)
plt.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2025-05-01  160.449997  161.949997  158.910004  161.300003  160.961014
# 2025-05-02  163.410004  164.970001  161.869995  164.029999  163.685272
# 2025-05-05  163.000000  165.389999  162.720001  164.210007  163.864883
# 2025-05-06  162.169998  164.800003  161.190002  163.229996  162.886948
# 2025-05-07  164.080002  165.000000  147.839996  151.380005  151.061859
# ...                ...         ...         ...         ...         ...
# 2025-10-28  269.690002  270.730011  266.500000  267.470001  267.470001
# 2025-10-29  267.750000  275.339996  267.670013  274.570007  274.570007
# 2025-10-30  291.589996  291.589996  280.059998  281.480011  281.480011
# 2025-10-31  283.209991  286.000000  277.029999  281.190002  281.190002
# 2025-11-03  282.179993  285.529999  279.799988  283.720001  283.720001
#
#                Volume
# Date
# 2025-05-01   30203200
# 2025-05-02   25715000
# 2025-05-05   21341800
# ...

# %%
import yfinance as yf
t = yf.Ticker("XYZ.MX")
print(t.history(period="5y").tail())
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2025-10-29 00:00:00-06:00  1430.000000  1430.000000  1400.000000  1400.000000
# 2025-10-30 00:00:00-06:00  1409.989990  1409.989990  1369.290039  1369.290039
# 2025-10-31 00:00:00-06:00  1405.180054  1405.180054  1405.180054  1405.180054
# 2025-11-03 00:00:00-06:00  1365.000000  1365.000000  1365.000000  1365.000000
# 2025-11-04 00:00:00-06:00  1365.000000  1365.000000  1365.000000  1365.000000
#
#                            Volume  Dividends  Stock Splits
# Date
# 2025-10-29 00:00:00-06:00      37        0.0           0.0
# 2025-10-30 00:00:00-06:00    4070        0.0           0.0
# 2025-10-31 00:00:00-06:00     843        0.0           0.0
# 2025-11-03 00:00:00-06:00      43        0.0           0.0
# 2025-11-04 00:00:00-06:00       4        0.0           0.0
